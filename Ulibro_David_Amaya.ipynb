# %% [markdown]
# **Ulibro**
# 1 y 2![Imagen de WhatsApp 2024-09-02 a las 12.31.12_abaa99df.jpg](data:image/jpeg;base64,...)![Imagen de WhatsApp 2024-09-02 a las 12.31.11_e45dc530.jpg](data:image/jpeg;base64,...)![Imagen de WhatsApp 2024-09-02 a las 12.31.11_cf8ab992.jpg](data:image/jpeg;base64,...)![Imagen de WhatsApp 2024-09-02 a las 12.31.11_3016a017.jpg](data:image/jpeg;base64,...)![Imagen de WhatsApp 2024-09-02 a las 12.31.11_3e9f6205.jpg](data:image/jpeg;base64,...)![Imagen de WhatsApp 2024-09-02 a las 12.31.10_9357a95d.jpg](data:image/jpeg;base64,...)
# ![Imagen de WhatsApp 2024-09-02 a las 12.31.11_c9284cab.jpg](data:image/jpeg;base64,...)![Imagen de WhatsApp 2024-09-02 a las 12.31.11_44243786.jpg](data:image/jpeg;base64,...)![Imagen de WhatsApp 2024-09-02 a las 12.31.10_2865e2bd.jpg](data:image/jpeg;base64,...)![Imagen de WhatsApp 2024-09-02 a las 12.31.10_13c78ed7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **PUNTO 3**
#
# Como aspectos claves de la charla puedo destacar: El uso de sabidura colectiva que tiene el profesor, puesto que se baso en que el promedio de las respuestas de un grupo de personas se puede acercar mucho al valor real.
# *tambien la interacción el publico, puesto que los participantes de la charla interactuaron en tiempo real utilizando la herramienta que se llama mentimeter

# %% [markdown]
# PUNTO 4
#
# ![WhatsApp Image 2024-09-02 at 12.27.57 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# PUNTO 5

# %%
import pandas as pd

# %%
df=pd.read_excel("ULIBRO.xlsx")

# %%
df
# Out:
#           Note: there are more sheets in this document Unnamed: 1 Unnamed: 2  \
# 0    Each session is found on its own sheet below. ...        NaN        NaN
# 1                                                 Date    Session      Voter
# 2                                           2024-08-27          1          1
# 3                                           2024-08-28          1          2
# 4                                           2024-08-28          1          3
# ..                                                 ...        ...        ...
# 270                                         2024-08-29          2        269
# 271                                         2024-08-29          2        270
# 272                                         2024-08-29          2        271
# 273                                         2024-08-29          2        272
# 274                                         2024-08-29          2        273
#
# ...
